# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datass = loadtxt("datass.dat").T

print datass
# Out:
# [[ 30.        29.983356  29.966757 ...,        nan        nan        nan]
#  [ 20.        19.974977  19.949919 ...,        nan        nan        nan]
#  [ 29.        28.984688  28.969414 ...,        nan        nan        nan]
#  ...,
#  [ 20.        19.998331  19.996645 ...,   0.46738    0.439258   0.411111]
#  [  1.         1.021993   1.043957 ...,  13.121337  13.121773  13.122201]
#  [ 20.        19.999165  19.99831  ...,   1.514442   1.487327   1.460186]]

# %%
plot = []
for i in range(30):
    plot.append([datass[2*i ], datass[2*i + 1]])
plot = np.array(plot)

# %%
for i in range(len(plot)):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(plot[i][0],plot[i][1])
    plt.show()
